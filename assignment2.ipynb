# %%
import pandas as pd
dataset=pd.read_csv("/content/iris.csv")
dataset.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
#mean of the data
import pandas as pd
ds=pd.read_csv("/content/iris.csv")
ds2=ds["sepal_width"].mean()
print("Mean is",ds2)
# Out:
# Mean is 3.0540000000000003

# %%
# median for data
import pandas as pd
ds=pd.read_csv("/content/iris.csv")
ds2=ds["sepal_width"].median()
print("Median is",ds2)
# Out:
# Median is 3.0

# %%
# max value of data
import pandas as pd
ds=pd.read_csv("/content/iris.csv")
ds2=ds["sepal_width"].max()
print("Maximum value is",ds2)
# Out:
# Maximum value is 4.4

# %%
# minimum value of data
import pandas as pd
ds=pd.read_csv("/content/iris.csv")
ds2=ds["sepal_width"].min()
print("Minimum value is",ds2)
# Out:
# Minimum value is 2.0

# %%
# mode of the data
import pandas as pd
ds=pd.read_csv("/content/iris.csv")
ds2=ds["sepal_width"].mode()
print("Mode is",ds2)
# Out:
# Mode is 0    3.0
# Name: sepal_width, dtype: float64

# %%
#Box plot
import pandas as pd
import matplotlib.pyplot as plot
dts1=pd.read_csv("/content/iris.csv")
b_plot=dts1.boxplot(column="sepal_length")
b_plot.plot()
plot.show()

# %%
# to find multiple box plot
import pandas as pd
import matplotlib.pyplot as plot
dts1=pd.read_csv("/content/iris.csv")
b_plot=dts1.boxplot(column=["sepal_length","sepal_length","petal_width" ,"petal_length"])
b_plot.plot()
plot.show()

# %%
import pandas as pd
d=pd.read_csv("/content/Toyota.csv")
d.head(100)
# Out:
#     Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0            0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1            1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2            2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3            3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4            4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ..         ...    ...   ...    ...      ...  ...       ...        ...   ...
# 95          95  19950  17.0  30351   Diesel   90       1.0          0  1995
# 96          96  15950  19.0  29435   Petrol   97       1.0          0  1400
# 97          97  15950  19.0  25948   Petrol   97       1.0          0  1400
# 98          98  18750  11.0  24500   Petrol  110       NaN          0  1600
# 99          99  17450  18.0  23902   Petrol   97       1.0          0  1400
#
#     Doors  Weight
# 0   three    1165
# ...

# %%
# code for scatter plot
import matplotlib.pyplot as plt
plt.scatter(d['Age'],d['Price'],c='blue')
plt.title('Scatter plot of Price vs Age of the Cars')
plt.xlabel('Age (months)')
plt.ylabel('Price (Euros)')
plt.show()

# %%
# for histogram
plt.hist(d['KM'], color = 'blue', edgecolor = 'white', bins = 5)
plt.title('Histogram of Kilometer')
plt.xlabel('Kilometer')
plt.ylabel('Frequency')
plt.show()

# %%
# Box plot
import numpy as np
counts = [979,120,12]
fuelType = ("Petrol","Diesel","CNG")
index = np.arange(len(fuelType))
plt.bar(index, counts, color=['black', 'blue', 'cyan'])
plt.title("Bar plot of fuel types")
plt.xlabel("Fuel Types")
plt.ylabel("Frequency")
plt.xticks(index,fuelType,rotation = 90)
plt.show()

# %%
# Bar plot generation using countplot function
import seaborn as sbs
sbs.countplot(x="FuelType",data=d)
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sbs.boxplot(y=d["Price"])
# Out:
# <Axes: ylabel='Price'>

# %%
sbs.countplot(x="FuelType", data=d, hue="Automatic")
# Out:
# <Axes: xlabel='FuelType', ylabel='count'>

# %%
sbs.boxplot(x =d['FuelType'], y =d["Price"])
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>

# %%
sbs.boxplot(x = "FuelType", y =d["Price"], hue = "Automatic", data =d)
# Out:
# <Axes: xlabel='FuelType', ylabel='Price'>
